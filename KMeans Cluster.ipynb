# %% [markdown]
# <a href="https://colab.research.google.com/github/watcharapornn/KKU_data_mining/blob/master/KMeans%20Cluster.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Generate Data

# %%
from sklearn.datasets import make_blobs

# %%
x,y = make_blobs(n_samples=300, centers=3, n_features=2,random_state=6)

# %%
x.shape
# Out:
# (300, 2)

# %%
from matplotlib import pyplot as plt
plt.scatter(x[:,0],x[:,1])

# %% [markdown]
# ##Import

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# ##Define = การกำหนด

# %%
KMclust = KMeans(n_clusters=5)

# %% [markdown]
# #Train

# %%
KMclust.fit(x)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# #Predict

# %%
label = KMclust.predict(x)

# %%
plt.scatter(x[:,0], x[:,1], c=label)

# %%
from google.colab import drive
drive.mount('/content/drive')

path = '/content/drive/My Drive'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import os

# %%
img = cv2.imread(os.path.join(path,'IMG_3341.JPG'))

# %%
RGB_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
